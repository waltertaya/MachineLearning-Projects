# %%
import pandas as pd

# %%
df = pd.read_csv('Fuel_Consumption_2000-2022.csv')

# %%
pd.set_option('display.max_columns', 50)
df.head()
# Out:
#    YEAR   MAKE    MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 0  2000  ACURA    1.6EL       COMPACT          1.6          4           A4
# 1  2000  ACURA    1.6EL       COMPACT          1.6          4           M5
# 2  2000  ACURA    3.2TL      MID-SIZE          3.2          6          AS5
# 3  2000  ACURA    3.5RL      MID-SIZE          3.5          6           A4
# 4  2000  ACURA  INTEGRA    SUBCOMPACT          1.8          4           A4
#
#   FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  COMB (mpg)  \
# 0    X               9.2             6.7              8.1          35
# 1    X               8.5             6.5              7.6          37
# 2    Z              12.2             7.4             10.0          28
# 3    Z              13.4             9.2             11.5          25
# 4    X              10.0             7.0              8.6          33
#
#    EMISSIONS
# 0        186
# 1        175
# 2        230
# 3        264
# 4        198

# %%
df.tail()
# Out:
#        YEAR   MAKE        MODEL  VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 22551  2022  Volvo  XC40 T5 AWD     SUV: Small          2.0          4
# 22552  2022  Volvo  XC60 B5 AWD     SUV: Small          2.0          4
# 22553  2022  Volvo  XC60 B6 AWD     SUV: Small          2.0          4
# 22554  2022  Volvo  XC90 T5 AWD  SUV: Standard          2.0          4
# 22555  2022  Volvo  XC90 T6 AWD  SUV: Standard          2.0          4
#
#       TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  \
# 22551          AS8    Z              10.7             7.7              9.4
# 22552          AS8    Z              10.5             8.1              9.4
# 22553          AS8    Z              11.0             8.7              9.9
# 22554          AS8    Z              11.5             8.4             10.1
# 22555          AS8    Z              12.4             8.9             10.8
#
#        COMB (mpg)  EMISSIONS
# 22551          30        219
# ...

# %%
df.sample(2)
# Out:
#       YEAR    MAKE            MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 6929  2008     BMW               M5      MID-SIZE          5.0         10
# 9889  2010  SUZUKI  SX4 SEDAN SPORT       COMPACT          2.0          4
#
#      TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  \
# 6929           M6    Z              19.9            11.9             16.3
# 9889           AV    X               8.9             6.7              7.9
#
#       COMB (mpg)  EMISSIONS
# 6929          17        375
# 9889          36        182

# %%
df.columns
# Out:
# Index(['YEAR', 'MAKE', 'MODEL', 'VEHICLE CLASS', 'ENGINE SIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUEL', 'FUEL CONSUMPTION', 'HWY (L/100 km)',
#        'COMB (L/100 km)', 'COMB (mpg)', 'EMISSIONS'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=22556, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22556 entries, 0 to 22555
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              22556 non-null  int64
#  1   MAKE              22556 non-null  object
#  2   MODEL             22556 non-null  object
#  3   VEHICLE CLASS     22556 non-null  object
#  4   ENGINE SIZE       22556 non-null  float64
#  5   CYLINDERS         22556 non-null  int64
#  6   TRANSMISSION      22556 non-null  object
#  7   FUEL              22556 non-null  object
#  8   FUEL CONSUMPTION  22556 non-null  float64
#  9   HWY (L/100 km)    22556 non-null  float64
#  10  COMB (L/100 km)   22556 non-null  float64
#  11  COMB (mpg)        22556 non-null  int64
#  12  EMISSIONS         22556 non-null  int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 2.2+ MB

# %%
df.describe()
# Out:
#                YEAR   ENGINE SIZE     CYLINDERS  FUEL CONSUMPTION  \
# count  22556.000000  22556.000000  22556.000000      22556.000000
# mean    2011.554442      3.356646      5.854141         12.763513
# std        6.298269      1.335425      1.819597          3.500999
# min     2000.000000      0.800000      2.000000          3.500000
# 25%     2006.000000      2.300000      4.000000         10.400000
# 50%     2012.000000      3.000000      6.000000         12.300000
# 75%     2017.000000      4.200000      8.000000         14.725000
# max     2022.000000      8.400000     16.000000         30.600000
#
#        HWY (L/100 km)  COMB (L/100 km)    COMB (mpg)     EMISSIONS
# count    22556.000000     22556.000000  22556.000000  22556.000000
# mean         8.919126        11.034341     27.374534    250.068452
# std          2.274764         2.910920      7.376982     59.355276
# min          3.200000         3.600000     11.000000     83.000000
# ...

# %%
df.shape
# Out:
# (22556, 13)

# %%
len(df)
# Out:
# 22556

# %%
df[['CYLINDERS', 'YEAR']]
# Out:
#        CYLINDERS  YEAR
# 0              4  2000
# 1              4  2000
# 2              6  2000
# 3              6  2000
# 4              4  2000
# ...          ...   ...
# 22551          4  2022
# 22552          4  2022
# 22553          4  2022
# 22554          4  2022
# 22555          4  2022
#
# [22556 rows x 2 columns]

# %%
df.select_dtypes('int')
# Out:
#        YEAR  CYLINDERS  COMB (mpg)  EMISSIONS
# 0      2000          4          35        186
# 1      2000          4          37        175
# 2      2000          6          28        230
# 3      2000          6          25        264
# 4      2000          4          33        198
# ...     ...        ...         ...        ...
# 22551  2022          4          30        219
# 22552  2022          4          30        219
# 22553  2022          4          29        232
# 22554  2022          4          28        236
# 22555  2022          4          26        252
#
# [22556 rows x 4 columns]

# %%
df.iloc[[5]]
# Out:
#    YEAR   MAKE    MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 5  2000  ACURA  INTEGRA    SUBCOMPACT          1.8          4           M5
#
#   FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  COMB (mpg)  \
# 5    X               9.3             6.8              8.2          34
#
#    EMISSIONS
# 5        189

# %%
df.iloc[1, 6]
# Out:
# 'M5'

# %%
df.iloc[:5, :5]
# Out:
#    YEAR   MAKE    MODEL VEHICLE CLASS  ENGINE SIZE
# 0  2000  ACURA    1.6EL       COMPACT          1.6
# 1  2000  ACURA    1.6EL       COMPACT          1.6
# 2  2000  ACURA    3.2TL      MID-SIZE          3.2
# 3  2000  ACURA    3.5RL      MID-SIZE          3.5
# 4  2000  ACURA  INTEGRA    SUBCOMPACT          1.8

# %%
df.loc[(df['MAKE'] == 'SUZUKI')]
# Out:
#        YEAR    MAKE             MODEL          VEHICLE CLASS  ENGINE SIZE  \
# 526    2000  SUZUKI            ESTEEM             SUBCOMPACT          1.6
# 527    2000  SUZUKI            ESTEEM             SUBCOMPACT          1.6
# 528    2000  SUZUKI      ESTEEM WAGON  STATION WAGON - SMALL          1.8
# 529    2000  SUZUKI      ESTEEM WAGON  STATION WAGON - SMALL          1.8
# 530    2000  SUZUKI  GRAND VITARA 4X4                    SUV          2.5
# ...     ...     ...               ...                    ...          ...
# 13117  2013  SUZUKI  SX4 HATCHBACK JX  STATION WAGON - SMALL          2.0
# 13118  2013  SUZUKI      SX4 SEDAN JA                COMPACT          2.0
# 13119  2013  SUZUKI   SX4 SEDAN JA/JE                COMPACT          2.0
# 13120  2013  SUZUKI   SX4 SEDAN SPORT                COMPACT          2.0
# 13121  2013  SUZUKI   SX4 SEDAN SPORT                COMPACT          2.0
#
#        CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 km)  \
# ...

# %%
df.query('YEAR == 2010')
# Out:
#       YEAR   MAKE          MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 8977  2010  ACURA            CSX       COMPACT          2.0          4
# 8978  2010  ACURA            CSX       COMPACT          2.0          4
# 8979  2010  ACURA            CSX       COMPACT          2.0          4
# 8980  2010  ACURA        MDX AWD           SUV          3.7          6
# 8981  2010  ACURA  RDX AWD TURBO           SUV          2.3          4
# ...    ...    ...            ...           ...          ...        ...
# 9993  2010  VOLVO   XC70 3.2 AWD           SUV          3.2          6
# 9994  2010  VOLVO    XC70 T6 AWD           SUV          3.0          6
# 9995  2010  VOLVO       XC90 3.2           SUV          3.2          6
# 9996  2010  VOLVO   XC90 3.2 AWD           SUV          3.2          6
# 9997  2010  VOLVO    XC90 V8 AWD           SUV          4.4          8
#
#      TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  \
# ...

# %%
start_size = 3.1
end_size = 3.6
df.query('(`ENGINE SIZE` >= @start_size) and (`ENGINE SIZE` <= @end_size)')
# Out:
#        YEAR        MAKE                      MODEL           VEHICLE CLASS  \
# 2      2000       ACURA                      3.2TL                MID-SIZE
# 3      2000       ACURA                      3.5RL                MID-SIZE
# 8      2000       ACURA                        NSX              SUBCOMPACT
# 51     2000         BMW                    M COUPE              TWO-SEATER
# 52     2000         BMW                 M ROADSTER             MINICOMPACT
# ...     ...         ...                        ...                     ...
# 22523  2022      Toyota             Tundra 4WD TRD  Pickup truck: Standard
# 22524  2022      Toyota          Tundra Hybrid 4WD  Pickup truck: Standard
# 22525  2022      Toyota  Tundra Hybrid 4WD TRD PRO  Pickup truck: Standard
# 22528  2022  Volkswagen              Atlas 4MOTION              SUV: Small
# 22530  2022  Volkswagen  Atlas Cross Sport 4MOTION              SUV: Small
#
#        ENGINE SIZE  CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  \
# ...

# %%
df.query('MAKE == "Toyota"')
# Out:
#        YEAR    MAKE                        MODEL           VEHICLE CLASS  \
# 18549  2018  Toyota                  4Runner 4WD           SUV: Standard
# 18550  2018  Toyota  4Runner 4WD (Part-Time 4WD)           SUV: Standard
# 18551  2018  Toyota                           86             Minicompact
# 18552  2018  Toyota                           86             Minicompact
# 18553  2018  Toyota                       Avalon                Mid-size
# ...     ...     ...                          ...                     ...
# 22522  2022  Toyota                   Tundra 4WD  Pickup truck: Standard
# 22523  2022  Toyota               Tundra 4WD TRD  Pickup truck: Standard
# 22524  2022  Toyota            Tundra Hybrid 4WD  Pickup truck: Standard
# 22525  2022  Toyota    Tundra Hybrid 4WD TRD PRO  Pickup truck: Standard
# 22526  2022  Toyota                    Venza AWD              SUV: Small
#
#        ENGINE SIZE  CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  \
# ...
